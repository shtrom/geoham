# %% [markdown]
# # GeoHam: Location-based Amateur Radio Repeater tools
#
# This library aims to provide tools to manipulate and use (fetch, map, output CHIRP configuration, filter, ...) various data sources about Amateur Radio repeaters around the world.
#
# This early version only works with data from the Wireless Institute of Australia, but the objective is to handle other data sources by adding a single subclass of a parser object.
#
# The library also comes with a simple command-line tool, `geoham` offering entry point into the library's functions.
#
# The main building blocks are the [Pandas](https://pandas.pydata.org/) and [folium](https://python-visualization.github.io/folium/) libraries.

# %% [markdown]
# ## Installation
#
#     pip install .

# %% [markdown]
# ## Command-line usage
#
# Just try out
#
#     geoham --help
#
# Don't forget to investigate the sub-commands, too.

# %% [markdown]
# ## Library usage
#
# If the following examples are not sufficient to get you going, you can also have a look at `geoham/cli.py`, which implements the command-line tool based on the library.
#
# To avoid too much noise in this notebook, we first make the logging quiet.

# %%
import logging

logging.basicConfig(level='ERROR')

# %% [markdown]
# ### Fetch the data

# %%
from geoham import downloader

d = downloader.Downloader()
csvfile=d.download() # No choice about what to download for now

# %% [markdown]
# ### Parse the data

# %%
from geoham import parser

p = parser.Parser()

with open(csvfile) as f:
    data, skipped = p.parse(f)
data
# Out:
#        Output     Input    Call mNemonic      Location           Service Area  \
# 1       29.12     29.12  VK2RMB   THills  Terrey Hills            Sydney 6/15
# 2       29.12     29.12  VK2RBH   Darlng    Mt Darling            Broken Hill
# 3       29.12     29.12  VK4RLB      NaN     Woodridge         Brisbane South
# 5       29.14     29.14  VK3RRU      NaN       Merbein                Mildura
# 6       29.62     29.52  VK5RSC      NaN   Mt Terrible               Adelaide
# ..        ...       ...     ...      ...           ...                    ...
# 835    446.50   1275.00  VK5RDC      NaN     The Bluff   Port Pirie & Whyalla
# 836   2415.00   1250.00  VK5RLZ      NaN     Elizabeth    Adelaide North 6/15
# 837   5815.00   5735.00  VK5RLZ      NaN     Elizabeth    Adelaide North 6/15
# 838  10350.00  10210.00  VK5RLZ      NaN     Elizabeth    Adelaide North 6/15
# 840    446.50   1250.00  VK7RTV      NaN      Stowport  Central NW Coast 6/15
#
#       Latitude   Longitude Status    ERP   HASL   T/O Sponsor  Tone Notes  \
# 1   -33.692994  151.222079      P    NaN  150.0   NaN     2MB   NaN     1
# 2   -32.022963  141.533162      O    NaN  400.0   NaN    2DPG   NaN    12
# 3   -27.627411  153.100191      O   25.0   60.0   4.0    4ARN  88.5     3
# 5   -34.168332  142.079050      O   20.0    NaN   2.5    3RSG   NaN     5
# 6   -35.331101  138.501776      O   40.0  410.0   3.0    5ARC   NaN     7
# ..         ...         ...    ...    ...    ...   ...     ...   ...   ...
# 835 -33.105937  138.164544      O  100.0  730.0   NaN    5DMC   NaN   105
# 836 -34.742448  138.649074      X  250.0   73.0  30.0     5LZ   NaN    93
# 837 -34.742448  138.649074      X    1.0   80.0  30.0     5LZ   NaN    93
# 838 -34.742448  138.649074      X   25.0   80.0  30.0     5LZ   NaN    93
# 840 -41.125805  145.907809      P   10.0  155.0  30.0     TNA   NaN    90
#
#                 Band  Duplex  Offset
# 1                17m     NaN     0.0
# 2                17m     NaN     0.0
# 3                17m     NaN     0.0
# 5                17m     NaN     0.0
# 6                17m    -1.0     0.1
# ..               ...     ...     ...
# 835             70cm     1.0   828.5
# 836             23cm    -1.0  1165.0
# 837   5815.000000MHz    -1.0    80.0
# 838  10350.000000MHz    -1.0   140.0
# 840             70cm     1.0   803.5
#
# [708 rows x 18 columns]

# %% [markdown]
# ### Show the data on a map

# %%
from geoham import displayer

d = displayer.LeafletDisplayer()
m = d.display(data)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f58f1ac6b74361511b92ea7bbd3f409e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f58f1ac6b74361511b92ea7bbd3f409e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f58f1ac6b74361511b92ea7bbd3f409e = L.map(
#                 &quot;map_f58f1ac6b74361511b92ea7bbd3f409e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac608cc8f157b1bd56e691bfca8809a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_ac608cc8f157b1bd56e691bfca8809a6.addTo(map_f58f1ac6b74361511b92ea7bbd3f409e);
#
#
#             var marker_cluster_af41c752a99db991dfdc442a69bf6b31 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_af41c752a99db991dfdc442a69bf6b31.addTo(map_f58f1ac6b74361511b92ea7bbd3f409e);
#
#
#             var feature_group_sub_group_3e9264344cfbff9ebd28907438b3b0e4 = L.featureGroup.subGroup(
#                 marker_cluster_af41c752a99db991dfdc442a69bf6b31
#             );
#
#
#             var marker_ca8e86f02329fecc8bea2f3aec7c7361 = L.marker(
#                 [-34.370997, 150.335746],
#                 {}
#             ).addTo(feature_group_sub_group_3e9264344cfbff9ebd28907438b3b0e4);
#
#
#             var icon_4a2a39c18bcb82102ba8d6451d60a4b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;signal&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ca8e86f02329fecc8bea2f3aec7c7361.setIcon(icon_4a2a39c18bcb82102ba8d6451d60a4b3);
#
#
#         var popup_7498dd303cadf07b072f54546cad34cf = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b91a4fb7a5b1d4fc555a4f6afc22631 = $(`&lt;div id=&quot;html_8b91a4fb7a5b1d4fc555a4f6afc22631&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;HRange (VK2RHR)&lt;/b&gt;&lt;br&gt;Location: High Range (Southern Highlands)&lt;br&gt;Out: 438.025 MHz / In: 433.025 MHz (5.0 MHz)&lt;/div&gt;`)[0];
#                 popup_7498dd303cadf07b072f54546cad34cf.setContent(html_8b91a4fb7a5b1d4fc555a4f6afc22631);
#
#
#
#         marker_ca8e86f02329fecc8bea2f3aec7c7361.bindPopup(popup_7498dd303cadf07b072f54546cad34cf)
#         ;
#
#
#
#
#             var marker_9e498759c4763c43e2ccad64d33e8200 = L.marker(
#                 [-32.890196, 151.538894],
#                 {}
#             ).addTo(feature_group_sub_group_3e9264344cfbff9ebd28907438b3b0e4);
#
#
#             var icon_b6009438dbe6ed4108b145739800a553 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;signal&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkred&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9e498759c4763c43e2ccad64d33e8200.setIcon(icon_b6009438dbe6ed4108b145739800a553);
#
#
#         var popup_232f25853dfe21f2c94c62cd7f213723 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_177b713d1cb0fbd9ae3332f47ce59cac = $(`&lt;div id=&quot;html_177b713d1cb0fbd9ae3332f47ce59cac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;b&gt;SgarL (VK2RNC)&lt;/b&gt;&lt;br&gt;Location: Mt Sugarloaf (Lower Hunter)&lt;br&gt;Out: 438.025 MHz / In: 433.025 MHz (5.0 MHz)&lt;/div&gt;`)[0];
#                 popup_232f25853dfe21f2c94c62cd7f213723.setContent(html_177b713d1cb0fbd9ae3332f47ce59cac);
#
#
#
#         marker_9e498759c4763c43e2ccad64d33e8200.bindPopup(popup_232f25853dfe21f2c94c62cd7f213723)
#         ;
#
#
#
#
#             var marker_33231ff82bd5007d5552b5a43d35a9c9 = L.marker(
#                 [-35.132713, 147.372072],
#                 {}
#             ).addTo(feature_group_sub_group_3e9264344cfbff9ebd28907438b3b0e4);
#
#
#             var icon_b229dd5fac37a7187b96c7a1bf52fced = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot

# %% [markdown]
# ## Author
#
# * Olivier Mehani <shtrom+geoham@ssji.net>, VK7SHM
