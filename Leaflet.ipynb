# %%
import logging

logging.basicConfig(level='ERROR')

# %%
from geoham import downloader

f = downloader.Downloader()
csvfile=f.download()

# %%
from geoham import parser

p = parser.Parser()

with open(csvfile) as f:
    data, skipped = p.parse(f)
data
# Out:
#          Output       Input    Call mNemonic             Location  \
# 1       29.1200     29.1200  VK2RMB   THills         Terrey Hills
# 2       29.1200     29.1200  VK2RBH   Darlng           Mt Darling
# 3       29.1200     29.1200  VK4RLB      NaN                Logan
# 4       29.1300     29.1300  VK2RNG    Werri           Werrington
# 5       29.1400     29.1400  VK3RRU      NaN              Merbein
# 6       29.6200     29.5200  VK5RSC      NaN          Mt Terrible
# 7       29.6300     29.5300  VK2RCZ      NaN           Lalor Park
# 8       29.6300     29.5300  VK4RPU      NaN             Mt Perry
# 9       29.6300     29.5300  VK7RMD      NaN            Mt Duncan
# 10      29.6400     29.5400  VK3RHF      NaN               Olinda
# 11      29.6500     29.5500  VK2RWI    Dural                Dural
# 12      29.6600     29.5600  VK4RKC      NaN           Ocean View
# 13      29.6700     29.5700  VK2RBM   Lawsn1               Lawson
# 14      29.6800     29.5800  VK6RHF      NaN              Leeming
# 15      29.6800     29.5800  VK7RHF      NaN        Roberts Bluff
# 17      53.5500     52.5500  VK2RSC   Lismor         Parrots Nest
# 18      53.5750     52.5750  VK2RPW      NaN           Grundy Mtn
# 19      53.6000     52.6000  VK2RNW    Kaput           Mt Kaputar
# 20      53.6250     52.6250  VK2RSN      NaN         Mt Sugarloaf
# 21      53.6500     52.6500  VK2RMP   Maddns       Maddens Plains
# 22      53.6750     52.6750  VK2RMB   THills         Terrey Hills
# 23      53.7000     52.7000  VK2RGN      NaN          Signal Hill
# 24      53.7250     52.7250  VK2RAG    Someb             Somersby
# 25      53.7500     52.7500  VK2RCB      NaN  Francis L/O Dorrigo
# 26      53.8500     52.8500  VK2RWI    Dural                Dural
# 27      53.8750     52.8750  VK2RBM   Lawsn1               Lawson
# 28      53.9250     52.9250  VK1RGI   Ginini            Mt Ginini
# 30      53.5000     52.5000  VK3RSA      NaN              Emerald
# 31      53.5500     52.5500  VK3RMH   WatlGn          Wattle Glen
# 32      53.5750     52.5750  VK3RDD      NaN             Cockatoo
# ..          ...         ...     ...      ...                  ...
# 790    439.8000    434.8000  VK5RBV      NaN         Mt Kitchener
# 791    438.3250    433.3250  VK5RCT      NaN               Moonta
# 792    438.1125    431.1125  VK5RDF      NaN              Crafers
# 793    439.8250    434.8250  VK5RSC      NaN          Mt Terrible
# 794    146.6750    146.0750  VK5RSV      NaN        Willunga Hill
# 795    146.8000    146.2000  VK6RTH    PerNE             Tic Hill
# 796    147.0000    146.4000  VK8RTE      NaN           Larrakeyah
# 798    426.2500    444.2500  VK2RGL   CbTree     Cabbage Tree Mtn
# 799    444.2500   1250.0000  VK2RTG      NaN              Kariong
# 800   1250.0000    444.2500  VK2RTS   Lawsn2               Lawson
# 801         NaN    444.2500  VK2RTV      NaN          St Leonards
# 802         NaN   2439.0000  VK2RTV      NaN          St Leonards
# 803   1250.0000    426.2500  VK2RFM      NaN              Oakdale
# 804   1250.0000    444.2500  VK2RFM      NaN              Oakdale
# 806    446.5000   1250.0000  VK3RTV      NaN               Olinda
# 807    446.5000   1255.0000  VK3RTV      NaN               Olinda
# 808    446.5000   1278.0000  VK3RTV      NaN               Olinda
# 809    446.5000  10410.0000  VK3RTV      NaN               Olinda
# 810   2415.0000   1250.0000  VK3RBO      NaN        Specimen Hill
# 812    444.2500   1250.0000  VK4RAT      NaN            Mt Stuart
# 813    444.2500   1250.0000  VK4RKP      NaN            Mt Crosby
# 814    446.5000         NaN  VK4RKC      NaN           Ocean View
# 815    446.5000   1283.0000  VK4RMG      NaN           Ocean View
# 816    446.5000         NaN  VK4RNC      NaN          Wilkes Knob
# 817    446.5000         NaN  VK4RTV      NaN           Ocean View
# 819    446.5000   1275.0000  VK5RDC      NaN            The Bluff
# 820   2415.0000   1250.0000  VK5RLZ      NaN            Elizabeth
# 821   5815.0000   5735.0000  VK5RLZ      NaN            Elizabeth
# 822  10350.0000  10210.0000  VK5RLZ      NaN            Elizabeth
# 824    446.5000   1250.0000  VK7RTV      NaN               Gawler
#
#               Service Area   Latitude   Longitude Status    ERP    HASL   T/O  \
# 1              Sydney 6/15 -33.692994  151.222079      P    NaN   150.0   NaN
# 2              Broken Hill -32.022963  141.533162      O    NaN   400.0   NaN
# 3                 Brisbane -27.627411  153.100191      O   25.0    60.0   4.0
# 4           Western Sydney -33.765599  150.740681      O    NaN     NaN   NaN
# 5                  Mildura -34.168332  142.079050      O   20.0     NaN   2.5
# 6                 Adelaide -35.331101  138.501776      O   40.0   410.0   3.0
# 7         Sydney West 8/15 -33.747338  150.833553      P    NaN     NaN   3.0
# 8               Monto 6/15 -25.191485  151.688007      P    NaN     NaN   NaN
# 9         NW Tasmania 6/15 -41.194584  146.035604      P   30.0   600.0   3.0
# 10               Melbourne -37.857864  145.364227      O  100.0   600.0   3.0
# 11             Sydney 6/15 -33.698742  151.055463      X   25.0   240.0   NaN
# 12          Brisbane North -27.145551  152.820209      O  100.0   530.0   5.0
# 13               Blue Mtns -33.719433  150.431585      O    NaN   900.0   3.0
# 14                   Perth -32.186175  116.070791      O   50.0   300.0   3.0
# 15                  Kaoota -42.919472  147.315947      O   50.0   710.0   5.0
# 17                 Lismore -28.857063  153.228511      O   20.0   185.0   3.0
# 18                  Walcha -31.326537  151.655979      O   50.0  1463.0   3.0
# 19           Narrabri 6/15 -30.278821  150.152139      X    NaN  1550.0   NaN
# 20               Newcastle -32.944671  151.515857      O    NaN   442.0   NaN
# 21     Wollongong - Sydney -34.263384  150.954594      O   40.0   465.0   4.0
# 22             Sydney 6/15 -33.692994  151.222079      X   50.0   150.0   3.0
# 23                Goulburn -34.756348  149.688344      O    NaN     NaN   NaN
# 24         Gosford - Wyong -33.360078  151.291215      O   50.0   320.0   3.0
# 25          Bellingen 7/17 -30.396516  152.688203      P   50.0   850.0   3.0
# 26                  Sydney -33.698742  151.055463      O   25.0   240.0   3.5
# 27               Blue Mtns -33.719433  150.431585      O    NaN   900.0   3.0
# 28       SE NSW - ACT 6/15 -35.529552  148.772605      P   35.0  1770.0   3.0
# 30          Melbourne 8/17 -37.932578  145.444156      P   25.0   316.0   3.0
# 31          Melbourne 6/15 -37.681545  145.195462      X   25.0   120.0   3.0
# 32          Dandenong 6/17 -37.942949  145.477019      X   30.0   385.0   3.5
# ..                     ...        ...         ...    ...    ...     ...   ...
# 790         Barossa Valley -34.571977  139.005935      O   50.0   580.0   3.5
# 791                 Moonta -34.047307  137.653630      O    NaN     NaN   NaN
# 792               Adelaide -34.998452  138.698773      O   50.0   610.0   3.0
# 793         Adelaide South -35.331101  138.501776      O   50.0   380.0   5.0
# 794         Adelaide South -35.273190  138.598021      O   50.0   320.0  10.0
# 795       Perth North East -31.825768  116.063938      O   60.0   230.0   4.0
# 796            Darwin City -12.455984  130.833233      O   50.0    59.0   4.0
# 798  Forster-Tuncurry 6/15 -32.257395  152.120465      P   50.0   685.0   NaN
# 799                Gosford -33.439521  151.297295      O    NaN   220.0   NaN
# 800              Blue Mtns -33.710693  150.444899      O  300.0   370.0  30.0
# 801            Sydney 6/15 -33.821258  151.189719      X  400.0    65.0   NaN
# 802            Sydney 6/15 -33.821258  151.189719      X  400.0    65.0   NaN
# 803                 Sydney -34.079735  150.503528      O  600.0   450.0   3.0
# 804                 Sydney -34.079735  150.503528      O  600.0   450.0   3.0
# 806              Melbourne -37.853928  145.366360      O   50.0   600.0   NaN
# 807              Melbourne -37.853928  145.366360      O   50.0   600.0   NaN
# 808              Melbourne -37.853928  145.366360      O   50.0   600.0   NaN
# 809              Melbourne -37.853928  145.366360      O   50.0   600.0   NaN
# 810                Bendigo -36.766320  144.244345      O  100.0   335.0   NaN
# 812             Townsville -19.343838  146.780685      O   20.0   584.0   NaN
# 813                Ipswich -27.527452  152.797919      O  100.0     NaN   NaN
# 814         Brisbane North -27.145551  152.820209      O  120.0   530.0   NaN
# 815         Brisbane North -27.145551  152.820209      O  120.0   530.0   NaN
# 816         Sunshine Coast -26.777270  152.910371      O  120.0   450.0   NaN
# 817         Brisbane North -27.145551  152.820209      O  120.0   530.0   NaN
# 819   Port Pirie & Whyalla -33.105937  138.164544      O  100.0   730.0   NaN
# 820    Adelaide North 6/15 -34.742448  138.649074      X  250.0    73.0  30.0
# 821    Adelaide North 6/15 -34.742448  138.649074      X    1.0    80.0  30.0
# 822    Adelaide North 6/15 -34.742448  138.649074      X   25.0    80.0  30.0
# 824  Central NW Coast 6/15 -41.200655  146.154779      P   10.0   155.0  30.0
#
#     Sponsor   Tone Notes             Band   Offset
# 1       2MB    NaN     1              17m     0.00
# 2      2DPG    NaN    12              17m     0.00
# 3      4ARN   88.5     3              17m     0.00
# 4      2THE    NaN    13              17m     0.00
# 5      3RSG    NaN     5              17m     0.00
# 6      5ARC    NaN     7              17m    -0.10
# 7      2CRZ    NaN   NaN              17m    -0.10
# 8       4PU    NaN   NaN              17m    -0.10
# 9       7NW    NaN   NaN              17m    -0.10
# 10      3UJ    NaN     8              17m    -0.10
# 11      2WI    NaN   NaN              17m    -0.10
# 12      4KI    NaN     9              17m    -0.10
# 13      2HZ    NaN   NaN              17m    -0.10
# 14      WRG  179.9    10              17m    -0.10
# 15      7HH   91.5    19              17m    -0.10
# 17     2SRC    NaN   NaN              10m    -1.00
# 18      NWR    NaN   NaN              10m    -1.00
# 19      2AJ    NaN   NaN              10m    -1.00
# 20      2FA    NaN   NaN              10m    -1.00
# 21     2AMW  123.0     2              10m    -1.00
# 22      2MB    NaN     1              10m    -1.00
# 23      2JQ    NaN   NaN              10m    -1.00
# 24      2EH   91.5    71              10m    -1.00
# 25      2EP    NaN   NaN              10m    -1.00
# 26      2WI    NaN   NaN              10m    -1.00
# 27      2HZ  123.0   NaN              10m    -1.00
# 28     1ACA   91.5   NaN              10m    -1.00
# 30      VSA   91.5   NaN              10m    -1.00
# 31     3CNE    NaN   NaN              10m    -1.00
# 32     3BJA   91.5   NaN              10m    -1.00
# ..      ...    ...   ...              ...      ...
# 790    5BRC    NaN    53            1.25m    -5.00
# 791    5ZSW   91.5   NaN            1.25m    -5.00
# 792     5DF    NaN   NaN            1.25m    -7.00
# 793    5ARC   91.5   NaN            1.25m    -5.00
# 794    5ARC   91.5    52               2m    -0.60
# 795     WRG    NaN    19               2m    -0.60
# 796     8DA  123.0   NaN               2m    -0.60
# 798    2GLR    NaN    90            1.25m    18.00
# 799     2EH    NaN    91             70cm   805.75
# 800    2FKO    NaN    90             33cm  -805.75
# 801    2TVG    NaN   NaN           nanMHz      NaN
# 802    2TVG    NaN   NaN           nanMHz      NaN
# 803    2CRZ    NaN    92             33cm  -823.75
# 804    2CRZ    NaN    92             33cm  -805.75
# 806     3WI    NaN    86             70cm   803.50
# 807     3WI    NaN    86             70cm   808.50
# 808     3WI    NaN    86             70cm   831.50
# 809     3WI    NaN    86             70cm  9963.50
# 810     3WI    NaN    91             23cm -1165.00
# 812    4WIT    NaN    91             70cm   805.75
# 813    4AKP    NaN    91             70cm   805.75
# 814     4KI    NaN    89             70cm      NaN
# 815    4RMG    NaN   109             70cm   836.50
# 816     4KI    NaN   110             70cm      NaN
# 817     4KI    NaN   111             70cm      NaN
# 819    5DMC    NaN   105             70cm   828.50
# 820     5LZ    NaN    93             23cm -1165.00
# 821     5LZ    NaN    93   5815.000000MHz   -80.00
# 822     5LZ    NaN    93  10350.000000MHz  -140.00
# 824     TNA    NaN    90             70cm   803.50
#
# [719 rows x 17 columns]

# %%
from geoham import displayer

d = displayer.LeafletDisplayer()
m = d.display(data)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
data[data.Call=='VK7RTC']
# Out:
#       Output    Input    Call mNemonic       Location    Service Area  \
# 599  439.825  434.825  VK7RTC      NaN  Mt Wellington          Hobart
# 600  439.825  434.825  VK7RTC      NaN       Mt Lloyd  Derwent Valley
# 601  439.825  434.825  VK7RTC      NaN       Grey Mtn  Huon & Channel
#
#       Latitude   Longitude Status   ERP    HASL  T/O Sponsor  Tone Notes  \
# 599 -42.894865  147.236213      O  50.0  1271.0  5.0    7TAZ  91.5    59
# 600 -42.844726  146.960276      O  50.0   932.0  5.0    7TAZ  91.5    59
# 601 -43.091506  147.116136      O  50.0   821.0  5.0    7TAZ  91.5    59
#
#       Band  Offset
# 599  1.25m    -5.0
# 600  1.25m    -5.0
# 601  1.25m    -5.0
